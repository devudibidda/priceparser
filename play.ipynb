# %%
import pandas as pd

# %%
df=pd.read_parquet(r"product_feeds_parquet/fragrances.parquet/")

# %%
(df[((df["sellingPrice"]-df["specialPrice"])/df["sellingPrice"])*100>50]).sort_values(by="discount",ascending=False)
# Out:
#                                                                  title  \
# __null_dask_index__
# 846                              Almas Aseel Herbal Attar(Musk Arabia)
# 679                  Emirates Aseel Floral Attar  (Floral) Floral A...
# 677                  Emirates Chastity French Fragrance Arabian Att...
# 505                  Al Nuaim White Musk Long Lasting Floral Attar(...
# 79                                 Al Nuaim Chille Floral Attar(Spicy)
# ...                                                                ...
# 930                       Rasasi Mukhallat Aloudh Floral Attar(Floral)
# 405                                 Al Nuaim Melody Floral Attar(Musk)
# 810                             Rockinclay 194909 Floral Attar(Floral)
# 15                          Al Nuaim Cherry Blast Floral Attar(Fruity)
# 676                  Vune Blue lady 6 ml (pack of 3) Floral Attar(W...
#
#                         mrp  sellingPrice  specialPrice  \
# __null_dask_index__
# ...
